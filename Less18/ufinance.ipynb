# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
tickers = ['AAPL','NVDA','GOOG']

for ticker in tickers:
    stock = yf.Ticker(ticker)
    info = stock.info
    print(stock)
# Out:
# yfinance.Ticker object <AAPL>
# yfinance.Ticker object <NVDA>
# yfinance.Ticker object <GOOG>

# %%
apple = yf.Ticker('AAPL')
nvidia = yf.Ticker('NVDA')
google = yf.Ticker('GOOGL')

# %%
stocks = [apple,nvidia,google]

# %%
apple.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
for stock in stocks:
    display(stock)
    display(stock.get_growth_estimates())
# Out:
# yfinance.Ticker object <AAPL>
#         stockTrend  indexTrend
# period
# 0q          0.0789      0.0934
# +1q         0.0948      0.1125
# 0y          0.0947      0.1404
# +1y         0.1211      0.1355
# LTG            NaN      0.0770
# yfinance.Ticker object <NVDA>
#         stockTrend  indexTrend
# period
# 0q          0.6377      0.0934
# +1q         0.4953      0.1125
# 0y          1.2780      0.1404
# +1y         0.5064      0.1355
# LTG            NaN      0.0770
# yfinance.Ticker object <GOOGL>
#         stockTrend  indexTrend
# period
# 0q          0.2932      0.0934
# +1q         0.0730      0.1125
# 0y          0.3756      0.1404
# +1y         0.1240      0.1355
# LTG            NaN      0.0770

# %%
apple.history(period='1mo')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
# 2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005  259.019989
# 2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998  255.589996
# 2024-12-30 00:00:00-05:00  252.229996  253.500000  250.750000  252.199997
# 2024-12-31 00:00:00-05:00  252.440002  253.279999  249.429993  250.419998
# 2025-01-02 00:00:00-05:00  248.929993  249.100006  241.820007  243.850006
# 2025-01-03 00:00:00-05:00  243.360001  244.179993  241.889999  243.360001
# 2025-01-06 00:00:00-05:00  244.309998  247.330002  243.199997  245.000000
# ...

# %%
'''stocks_1mo = {}

for stock in stocks:
    df_f'{stock}' = pd.DataFrame(stock.history(period='1mo')))'''
# Out:
# "stocks_1mo = {}\n\nfor stock in stocks:\n    df_f'{stock}' = pd.DataFrame(stock.history(period='1mo')))"

# %%
apple_1mo = pd.DataFrame(apple.history(period='1y'))
google_1mo = pd.DataFrame(google.history(period='1y'))
nvidia_1mo = pd.DataFrame(nvidia.history(period='1y'))

# %%
apple.fast_info['tenDayAverageVolume']
# Out:
# 49438970

# %%
apple_1mo
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
# 2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005  259.019989
# 2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998  255.589996
# 2024-12-30 00:00:00-05:00  252.229996  253.500000  250.750000  252.199997
# 2024-12-31 00:00:00-05:00  252.440002  253.279999  249.429993  250.419998
# 2025-01-02 00:00:00-05:00  248.929993  249.100006  241.820007  243.850006
# 2025-01-03 00:00:00-05:00  243.360001  244.179993  241.889999  243.360001
# 2025-01-06 00:00:00-05:00  244.309998  247.330002  243.199997  245.000000
# ...

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(14, 8))

# Plot Apple
mpf.plot(apple_1mo, type='candle', style='yahoo', ax=ax, axtitle='Apple')

# Plot Google on the same axes
mpf.plot(google_1mo, type='candle', style='yahoo', ax=ax, axtitle='Google')

# Plot Nvidia on the same axes
mpf.plot(nvidia_1mo, type='candle', style='yahoo', ax=ax, axtitle='Tickers')

# Show the plot
plt.show()

# %%
mpf.plot(apple_1mo, type='candle', style='yahoo', volume= True, axtitle='Apple')
