# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
df=pd.read_csv("Startup.csv")
df

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
plt.figure(figsize=(8, 5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.plot(kind='scatter',x='R&D Spend',y='Profit')
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
df.plot(kind='scatter',x='Marketing Spend',y='Profit')
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %%
df.plot(kind='scatter',x='Administration',y='Profit')
# Out:
# <Axes: xlabel='Administration', ylabel='Profit'>

# %%
import pygwalker as pyg

# %%
x =df[['R&D Spend','Marketing Spend','Administration']]
y=df[['Profit']]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.948981506258928

# %%
print( model.intercept_)
print( model.coef_)
# Out:
# [44497.02268853]
# [[0.80001714 0.03778787 0.01144211]]

# %%
df_comp=y_test
df_comp['predictions']=model.predict(x_test)
df_comp
# Out:
#        Profit    predictions
# 37   89949.14   87785.848270
# 14  132602.65  151937.981085
# 21  111313.02  120295.869526
# 32   97427.84   98445.205897
# 22  110352.25  116560.622543
# 1   191792.06  193084.030399
# 26  105733.54  111476.096492
# 46   49490.75   58101.918559
# 42   71498.49   70103.431321
# 47   42559.73   46046.591998
# 16  126992.93  118289.255864
# 24  108552.04  112581.562357
# 7   155752.60  162641.542071
# 45   64926.08   46789.741671
# 18  124266.90  130348.718710

# %%
plt.scatter(x_train[['R&D Spend']], y_train, color="g")

plt.plot(x_test[['R&D Spend']], model.predict(x_test), color="k")
